# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# EXPORTACIONES EN COLOMBIA

# %%
expo = pd.read_csv('/content/expooo.csv', delimiter = ';')
expo = expo.set_index('year')
expo
# Out:
#       United States of America    China   Panama  Ecuador   Brazil
# year
# 2001                   5344533    19907   265163   699929   166704
# 2002                   5328470    27825   214697   811559   107823
# 2003                   6160245    82204   170524   778966    92848
# 2004                   7042201   137504   216490  1010665   141188
# 2005                   8851631   236689   264140  1324408   141348
# 2006                   9948230   452420   257484  1237076   190701
# 2007                  10609167   784758   246322  1276036   471366
# 2008                  14288833   442953   318980  1499562   648941
# 2009                  13123466   949726   309589  1257334   576636
# 2010                  17143277  1966624   936345  1824535  1040263
# 2011                  21948535  1989061  1956816  1908592  1370308
# 2012                  22216238  3343081  2916011  1910498  1290579
# 2013                  18692895  5102171  3219265  1974770  1590629
# ...

# %%
sns.lineplot(data=expo , y= 'United States of America', x='year')

# %% [markdown]
# En la gráfica anterior tenemos representadas las exportaciones de Colombia hacía su mayor importador que es Estados Unidos. Se puede evidenciar un periodo de expansión desde el 2001 hasta el 2010. Desde el 2010 hasta el 2012 se llega al auge en las exportaciones hacía EEUU, terminando con una recesión entre el 2012 y el 2015. Por último, desde el 2015 dichas exportaciones tratan de mantenerse constantes, oscilando entre 10052617 dólares y 12265471 dólares.

# %% [markdown]
# Exportaciones en Colombia

# %%
sns.lineplot(data=expo)

# %% [markdown]
# Ahora, teniendo en cuenta todas las exportaciones de Colombia en los 5 primeros países importadores (Estados Unidos, Chins, Panama, Ecuador y Brazil), tenemos un comportamiento similar a la gráfica anterior. Entre 2001-2010 las exportaciones se encuentran en un constante crecimiento, hasta llegar a los años 2010-2012 lo que sería el auge para las exportaciones colombianas, principalmente con EEUU, China y Panama. Para los años siguientes se entra a una recesión, terminando con una caída más entre los años 2018 a 2020 aproximadamente. Para el caso de Ecuador y Brazil se tienen exportaciones constantes entre 2012 y 2014, a comparación de los paises anteriores.

# %% [markdown]
# IMPORTACIONES EN COLOMBIA

# %%
impo = pd.read_csv('/content/impooo.csv', delimiter = ';')
impo = impo.set_index('year')
impo
# Out:
#       United States of America     China   Mexico   Brazil  Germany
# year
# 2001                   4442775    475405   596168   582060   560090
# 2002                   4051198    532847   677990   642840   508304
# 2003                   4112710    688673   744375   769003   611672
# 2004                   4806760   1244730   935642  1352172   686601
# 2005                   6033241   1616821  1757068  1383387   773661
# 2006                   6960605   2219273  2290571  1884885   933215
# 2007                   8631115   3326574  3072565  2393940  1204874
# 2008                  11583019   4548798  3125980  2328416  1557401
# 2009                   9505791   3715170  2297888  2146578  1338394
# 2010                  10531813   5477428  3856674  2369637  1657634
# 2011                  13663338   8176440  6059027  2740248  2215150
# 2012                  14140116   9564690  6362176  2795908  2239577
# 2013                  16428423  10362788  5495958  2590480  2206909
# ...

# %%
sns.lineplot(data=impo, y='China', x='year')

# %% [markdown]
# En la gráfica anterior tenemos las importaciones de Colombia por parte del producto de China. Se puede evidenciar un crecimiento constante desde el año 2001 hasta el año 2013 aprox, llegando al auge en entre 2014 y 2015, ya que apartir de ahí comienza una recesión, es decir, una caída de las importaciones entre el 2015 hasta el 2016. Por último, aumentan las importacuones desde el 2017 hasta el 2018, volviendose constantes hasta el 2020.

# %% [markdown]
# Importaciones en Colombia

# %%
sns.lineplot(data=impo)

# %% [markdown]
# Ahora, teniendo en cuenta los 5 primeros importadores (Estados Unidos, China, Mexico, Brazil y Alemania) hacía Colombia podemos observar la gráfica anterior. Para el caso de Estados Unidos y China se puede observar un caso similar (2001-2013:crecimiento constante y 2014-2020: auge y después recesión). Para el caso de México, se tiene el auge entre los años 2011 y 2012, y desde ahí una caída constante de las importaciones colombianas. Por último, Brazil y Alemania, que a compración de los otros países, tuvieron un comportamiento menos oscilante: Para Brazil el mayor auge fue entre 2011 y 2012 y para Alemania fue en el 2013.

# %% [markdown]
# **Visualización de Exportaciones e Importaciones en Colombia Diferenciado por Producto**

# %% [markdown]
# A) Lista de mercados proveedores de un producto exportado por Colombia:
#
# Producto: 27 Combustibles minerales, aceites minerales y productos de su destilacion; sustancias bituminosas; minerales...

# %%
expo_mine = pd.read_csv('/content/producto exportado por Colombia (combustibles minerales, aceites minerales...).csv', delimiter = ';')
expo_mine = expo_mine.set_index('Year')
expo_mine
# Out:
#          World  United States of America    China   Panama   Turkey    India
# Year
# 2001   4465293                   3189107        0   123329        0        0
# 2002   4273430                   3114865       56    83695     4261        0
# 2003   4869051                   3270342     1925    11595    47827        0
# 2004   6174539                   3854984     6386    29236    61959     2611
# 2005   8316330                   4984862        0    79071   107975        0
# 2006   9373868                   6076832        0    35753   122426      743
# 2007  10872155                   6742398        0    11178   127717       66
# 2008  17295012                  10082712    65506    36910   167966      336
# 2009  15780900                   8883872   427366    25570   303189   436210
# 2010  22564446                  12071173  1319062   629655   190376   332120
# 2011  36489143                  16091860  1345020  1530349   563040   714390
# ...

# %%
sns.lineplot(data=expo_mine)

# %% [markdown]
# Ahora, en este caso tenemos el comportamiento de las exportaciones de Colombia por producto, en este caso, el producto son los minerales en sus diferentes presentaciones. En este caso, el comportamiento mundial esta representado por la línea azul, la cual nos muestra que hubo una expansión de la exportación de minerales desde el año 2001 hasta el año 2011, llegando así al auge entre 2011 hasta 2014. Entre los años 2014 hasta el 2016 hay una caída muy importante. A partir de ahí, desde el 2016 aumentaron dichas exportaciones hasta el 2018, ya que se vuelve a prsentar una caída hasta el 2020.
#
# Fijandonos en el comportamiento de cada país, tenemos que Estados Unidos sigue un comportamiento muy similar al mundial. En el caso de China, las exportaciones por parte de Colombia llegaron al auge en el año 2014, y a partir de allí, siguieron los pasos como la representación mundial. Por último, es importante mencionar la fuerza que tomaron las exportaciones de minerales en colombia con Turquía y con India, llegando en el 2014 a 842457 dólares y	2641557 dólares en exportaciones, respectivamente.

# %% [markdown]
# A) Lista de mercados proveedores de un producto importado por Colombia:
#
# Producto: 27 Combustibles minerales, aceites minerales y productos de su destilacion; sustancias bituminosas; minerales...

# %%
impo_mine = pd.read_csv('/content/producto importado por Colombia (combustibles minerales, aceites minerales...).csv', delimiter = ';')
impo_mine = impo_mine.set_index('Year')
impo_mine
# Out:
#         World  United States of America  Free Zones  Ecuador  United Kingdom  \
# Year
# 2001   196900                     35323           0       76             197
# 2002   195934                     47323           0     9875             238
# 2003   244251                     63580         658    13364             302
# 2004   268061                     77446           0    21691            1843
# 2005   551269                    204896        1522     2124             313
# 2006   687315                    235372        2964     1918             377
# 2007   913811                    393830        1913     5378             742
# 2008  1815188                   1138964        5119     6445           37365
# 2009  1239237                    926644        2640     3257            4789
# 2010  2081112                   1601400        2543     2943             507
# 2011  3854233                   2559414         480     3335            1377
# ...

# %%
sns.lineplot(data=impo_mine)

# %% [markdown]
# En el caso de las importaciones de minerales en Colombia se puede evidenciar una gran diferencia con la gráfica de exportaciones de minerales. Mientras que en las exportaciones de minerales hubo una caída importante desde el año 2014, en el caso de las importaciones de minerales en Colommbia para el mismo año se llegó al auge.
#
# Como ha sido evidente, Estados Unidos sigue teniendo un comportamiento muy similar que el comportamiento mundial. A comparación de Free Zones que para los años 2016 y 2017 tuvieron un auge con las importaciones colombianas, mientras que en el comportamiento mundial para los mismos años hubo una recesión. Los otros países tuvieron un comportamiento más o menos constante.

# %% [markdown]
# B) Lista de mercados importadores de un producto exportado por Colombia:
#
# Producto: 09 Café, té, mate y especias

# %%
expo_cafe = pd.read_csv('/content/producto exportado por Colombia (cafe te mate especias).csv', delimiter = ';')
expo_cafe = expo_cafe.set_index('Year')
expo_cafe
# Out:
#         World  United States of America  Germany   Japan  Belgium  Canada
# Year
# 2001   773930                    250096   147739  104214    31034   43811
# 2002   786214                    267587   135430  123457    33058   42291
# 2003   817596                    297222   129135  119418    41559   42144
# 2004   968855                    348727   133634  161789    51126   57798
# 2005  1497878                    538657   201399  226870    93115   94140
# 2006  1491981                    536550   201667  210524    78141   83730
# 2007  1740212                    617100   237745  214205   123516   86633
# 2008  1923022                    719813   203721  245692   131231  106470
# 2009  1581061                    680533    88466  249990   102317  100770
# 2010  1921672                    766418    79416  372526   150077  149056
# 2011  2665457                   1122655   138104  351014   222200  183903
# 2012  1964992                    825164   104593  214541   159513  146135
# ...

# %%
sns.lineplot(data=expo_cafe)

# %% [markdown]
# Para esta gráfica tenemos el comportamiento de las exportaciones de Colombia por producto, en este caso, el producto son el café, el té, el mate y las especias. Con respecto al comportamiento mundial (línea azul) se puede evidenciar que las exportaciones de café, té, mate y especias no han sido muy estables. Se tiene que para el año 2009 y para el año 2012 las exportaciones se encuentran en depresión, a comparación del año 2011 que se llega a un auge importante con 2665457 dólares. Lo que si se puede evidenciar, es que estas exportaciones siempre han seguido un camino al crecimiento, ya que para el 2020 se encuentra en un punto alto con 2537462 dólares.
#
# En este caso, se puede evidenciar que todos los países siguen un comportamiento similar al mundial, menos Alemania. Las exportaciones de este producto en Alemania tuvo su auge entre los años 2005 al 2008 con 201399 dólares y 203721 dólares, respectivamente, mientras que en el auge mundial, alemania estuvo con solo 138104 dólares en exportaciones.

# %% [markdown]
# B) Lista de mercados importadores de un producto importado por Colombia:
#
# Producto: 09 Café, té, mate y especias

# %%
impo_cafe = pd.read_csv('/content/producto importado por Colombia (cafe te mate especias).csv', delimiter = ';')
impo_cafe = impo_cafe.set_index('Year')
impo_cafe
# Out:
#        World  Brazil    Peru  Sri Lanka  Honduras  India
# Year
# 2001   13087    2214    2048       2747         0    537
# 2002   12233    3534    1859       2725         0    122
# 2003    8647    1073    1707       2764         0     14
# 2004   11599     178    2439       3430         0      4
# 2005   32051     206    7706       2905         0    101
# 2006   36272     347   10104       4291         0    295
# 2007   24654     688    5145       4478         0    488
# 2008   33972     366    9638       5542         0   3585
# 2009   94083    3089   43988       4849         0   1540
# 2010   91280    2609   39847       4729         0   1387
# 2011  188775     693   85566       7354         0   2612
# 2012  191680   11851  100730       7104         0   2620
# 2013   69311    1066   34241       7427         0   3148
# 2014   54291    8887   16127       7371         0   2994
# 2015   32359     979    7895       6679         0   3113
# ...

# %%
sns.lineplot(data=impo_cafe)

# %% [markdown]
# Ahora, teniendo en cuenta las importaciones de café, té, mate y especias en Colombia tenemos que el comportamiento mundial estuvo en auge en 2011-2012. Desde el 2001 hasta el 2010 un crecimiento muy marcado, mientras que para los años 2012 hasta el 2016 hubo una caída importante. A partir de ahí, un crecimiento hasta el 2020 con 125273 dólares en importaciones de café, té, mate y especias en Colombia.
#
# En este caso, Perú tiene un comportamiento similar al mundial, llegando al auge en 2011 con 100730 dólares, aparte de su otro auge en 2018 con 33471 dólares. Para el caso de Brazil es importante mencionar el gran crecimiento que hubo de las importaciones en Colombia de este producto desde el año 2018 hasta el 2020, con 29231 dólares y 64651 dólares, respectivamente.
